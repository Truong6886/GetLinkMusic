# %%
import requests
import pandas as pd
import re

def extract_album_id(album_link):
    match = re.search(r'/album/.*?/(\w+)\.html', album_link or "")
    return match.group(1) if match else "N/A"

def determine_album_type(track_count):
    if track_count == 1:
        return "Single"
    elif 2 <= track_count <= 6:
        return "EP"
    else:
        return "Regular"

def fetch_artist_songs(artist_name):
    url = f"http://localhost:5000/api/artistsongs?name={artist_name}"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        songs = data.get("songs", [])
        
        records = []
        album_tracks = {}
        
        for song in songs:
            tracklist = song.get("tracklist", [])
            
            if not tracklist:
                tracklist = [{"title": song.get("title", "N/A")}]  # Nếu không có danh sách bài hát, lấy luôn tên bài hát
            
            album_id = extract_album_id(song.get("albumLink", "") or "")
            
            if album_id not in album_tracks:
                album_tracks[album_id] = len(tracklist)
            
            for track in tracklist:
                records.append({
                    "album_id": album_id,
                    "album_name": song.get("album", song.get("title", "N/A")),
                    "track_title": track["title"],
                    "release_date": song.get("releaseDate", "Unknown"),
                    "provided_by": song.get("providedBy", "Unknown"),
                    "featured_artists": song.get("featuredArtists", "Unknown"),
                    "album_owner": song.get("albumOwner", "Unknown"),
                    "linkzingmp3": song.get("link", "N/A")
                })
        
        df = pd.DataFrame(records)
        df = df.drop_duplicates(subset=["album_id", "album_name", "track_title"])
        
        # Thêm cột phân loại album
        df["album_type"] = df["album_id"].map(lambda x: determine_album_type(album_tracks.get(x, 1)))
        
        return df
    else:
        print("Error fetching data:", response.status_code)
        return None

artist_name='Obito'
df = fetch_artist_songs(artist_name)

# %%
df
# Out:
#      album_id                                         album_name  \
# 0         N/A                                        Shay Nắnggg
# 1    ZA9UAD8I                               Simple Love (Single)
# 2    6BFZIF6B                                Dám Rực Rỡ (Single)
# 3    6B6ZCOD6                                 Si me you (Single)
# 4         N/A                                When You Look at Me
# 5    6B7C9ZO0         Tiền Là Chi (Mcredit x OCEAN MOB) (Single)
# 6    SC0EC0B6                                             OMERTÀ
# 7    6BFOFUOD                                Phong Long (Single)
# 8    6B0AIO0I                                 Soju Love (Single)
# 9    6CUCB0OO  Chỉ Cần Bạn Có Mặt (Ngày Hội Liên Quân 2024) (...
# 10   68EOUBE6                                      LOST (Single)
# 11   6BOEOFWO                                  Mưa Hồng (Single)
# 12   6BEEZ96E  Buồn Hay Vui (feat. RPT MCK, Obito, Ronboogz &...
# 13   6CZ7U60W                                               Lặng
# 14   6CZ7U60W                                               Lặng
# 15   6BW6Z66W                     Happy Birthday To You (Single)
# 16   6BWO88DD                               Let's Leave (Single)
# 17   6BDOI9WU                                           Đánh Đổi
# 18   6BDOI9WU                                           Đánh Đổi
# 19   6BDOI9WU                                           Đánh Đổi
# 20   6BDOI9WU                                           Đánh Đổi
# 21   6BDOI9WU                                           Đánh Đổi
# 22   6BDOI9WU                                           Đánh Đổi
# 23   6BDOI9WU                                           Đánh Đổi
# 24   6BDOI9WU                                           Đánh Đổi
# 25   6BDOI9WU                                           Đánh Đổi
# 26   6BDOI9WU                                           Đánh Đổi
# 27   6BDOI9WU                                           Đánh Đổi
# 28   6BDOI9WU                                           Đánh Đổi
# 29   6BDOI9WU                                           Đánh Đổi
# 7      Universal Music Group
# 8      Universal Music Group
# 9             TECHBEAT Music
# 10     Universal Music Group
# 11     Universal Music Group
# 12      Warner Music Vietnam
# 13      Warner Music Vietnam
# 14      Warner Music Vietnam
# 15            Yin Yang Media
# 16     Universal Music Group
# 17      Warner Music Vietnam
# 18      Warner Music Vietnam
# 19      Warner Music Vietnam
# 20      Warner Music Vietnam
# 21      Warner Music Vietnam
# 22      Warner Music Vietnam
# 23      Warner Music Vietnam
# 24      Warner Music Vietnam
# 25      Warner Music Vietnam
# 26      Warner Music Vietnam
# 27      Warner Music Vietnam
# 28      Warner Music Vietnam
# 29      Warner Music Vietnam
# 30      Warner Music Vietnam
# 31      Warner Music Vietnam
# 32      Warner Music Vietnam
# 33      Warner Music Vietnam
# 34      Warner Music Vietnam
# 35      Warner Music Vietnam
# 36      Warner Music Vietnam
# 37      Warner Music Vietnam
# 58     Universal Music Group
# 79     Universal Music Group
# 80                      None
# 161                     None
# 262                     None
# 283              The Orchard
# 286     Warner Music Vietnam
# 327     Warner Music Vietnam
# 328     Warner Music Vietnam
#
#                                      featured_artists  \
# 0                                         AMEE, Obito
# 1                             Obito, Seachains, Davis
# 2               GREY D, HIEUTHUHAI, Wren Evans, Obito
# 3                                               Obito
# 4                                               Obito
# 5    OCEAN MOB, wAvy, Willistic, Gill, xolitxo, Obito
# 6                       $A Milo, Gxxfy, Obito, B-Wine
# 7                                Low G, Obito, WOKEUP
# 8                                               Obito
# 9       Obito, Wxrdie, Cheng, Garena Liên Quân Mobile
# 10                                              Obito
# 11                                 Hoàng Duyên, Obito
# 12                VSOUL, MCK, Obito, Ronboogz, Boyzed
# 13                                       Shiki, Obito
# 14                                       Shiki, Obito
# 15                            AMEE, Hoàng Dũng, Obito
# 16                                              Obito
# 17                              Obito, Shiki, Lăng LD
# 18                              Obito, Shiki, Lăng LD
# 19                              Obito, Shiki, Lăng LD
# 20                              Obito, Shiki, Lăng LD
# 21                              Obito, Shiki, Lăng LD
# 22                              Obito, Shiki, Lăng LD
# 23                              Obito, Shiki, Lăng LD
# 24                              Obito, Shiki, Lăng LD
# 25                              Obito, Shiki, Lăng LD
# 26                              Obito, Shiki, Lăng LD
# 27                              Obito, Shiki, Lăng LD
# 28                              Obito, Shiki, Lăng LD
# 29                              Obito, Shiki, Lăng LD
# 30                              Obito, Shiki, Lăng LD
# 31                              Obito, Shiki, Lăng LD
# 32                              Obito, Shiki, Lăng LD
# 33                              Obito, Shiki, Lăng LD
# 34                              Obito, Shiki, Lăng LD
# 35                              Obito, Shiki, Lăng LD
# 36                              Obito, Shiki, Lăng LD
# 37                              Tyronee, VSTRA, Obito
# 58                                              Obito
# 79                                              Obito
# 80                                              Obito
# 161                                  Lope Phạm, Obito
# 262                                  Obito, Seachains
# 283                       VSTRA, TGSN, Tyronee, Obito
# 286                                      VSOUL, Obito
# 327                              Richie D. ICY, Obito
# 328                              Richie D. ICY, Obito
#
#                                          album_owner  \
# 0                                               None
# 1                                   Obito, Seachains
# 2    GREY D, HIEUTHUHAI, Wren Evans, Obito, Kai Đinh
# 3                                              Obito
# 4                                               None
# 5                                          OCEAN MOB
# 6                                     $A Milo, Gxxfy
# 7                               Obito, Low G, WOKEUP
# 8                                              Obito
# 9      Obito, Wxrdie, Cheng, Garena Liên Quân Mobile
# 10                                             Obito
# 11                                Hoàng Duyên, Obito
# 12               VSOUL, MCK, Obito, Ronboogz, Boyzed
# 13                                             Shiki
# 14                                             Shiki
# 15                           AMEE, Hoàng Dũng, Obito
# 16                                             Obito
# 17                                      Obito, Shiki
# 18                                      Obito, Shiki
# 19                                      Obito, Shiki
# 20                                      Obito, Shiki
# 21                                      Obito, Shiki
# 22                                      Obito, Shiki
# 23                                      Obito, Shiki
# 24                                      Obito, Shiki
# 25                                      Obito, Shiki
# 26                                      Obito, Shiki
# 27                                      Obito, Shiki
# 28                                      Obito, Shiki
# 29                                      Obito, Shiki
# 30                                      Obito, Shiki
# 31                                      Obito, Shiki
# 32                                      Obito, Shiki
# 33                                      Obito, Shiki
# 34                                      Obito, Shiki
# 35                                      Obito, Shiki
# 36                                      Obito, Shiki
# 37                                           Tyronee
# 58                                             Obito
# 79                                             Obito
# 80                                              None
# 161                                             None
# 262                                             None
# 283                             VSTRA, TGSN, Tyronee
# 286                                     VSOUL, Obito
# 327                             Richie D. ICY, Obito
# 328                             Richie D. ICY, Obito
#
#                                            linkzingmp3 album_type
# 0    https://zingmp3.vn/bai-hat/Shay-Nanggg-AMEE-Ob...     Single
# 1    https://zingmp3.vn/bai-hat/Simple-Love-Obito-S...     Single
# 2    https://zingmp3.vn/bai-hat/Dam-Ruc-Ro-GREY-D-H...     Single
# 3    https://zingmp3.vn/bai-hat/Si-me-you-Obito/Z6W...     Single
# 4    https://zingmp3.vn/bai-hat/When-You-Look-at-Me...     Single
# 5    https://zingmp3.vn/bai-hat/Tien-La-Chi-Mcredit...     Single
# 6    https://zingmp3.vn/bai-hat/BUSINESS-MODE-A-Mil...     Single
# 7    https://zingmp3.vn/bai-hat/Phong-Long-Low-G-Ob...     Single
# 8    https://zingmp3.vn/bai-hat/Soju-Love-Obito/ZZ7...     Single
# 9    https://zingmp3.vn/bai-hat/Chi-Can-Ban-Co-Mat-...     Single
# 10   https://zingmp3.vn/bai-hat/LOST-Obito/ZUODFUEI...     Single
# 11   https://zingmp3.vn/bai-hat/Mua-Hong-Hoang-Duye...     Single
# 12   https://zingmp3.vn/bai-hat/Buon-Hay-Vui-feat-R...     Single
# 13   https://zingmp3.vn/bai-hat/1000-Anh-Mat-Shiki-...         EP
# 14   https://zingmp3.vn/bai-hat/1000-Anh-Mat-Shiki-...         EP
# 15   https://zingmp3.vn/bai-hat/Happy-Birthday-To-Y...     Single
# 16   https://zingmp3.vn/bai-hat/Let-s-Leave-Obito/Z...     Single
# 17   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 18   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 19   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 20   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 21   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 22   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 23   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 24   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 25   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 26   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 27   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 28   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 29   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 30   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 31   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 32   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 33   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 34   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 35   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 36   https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 37   https://zingmp3.vn/bai-hat/Track-06-Tyronee-VS...     Single
# 58   https://zingmp3.vn/bai-hat/Our-Vintage-Look-Ob...     Single
# 79   https://zingmp3.vn/bai-hat/Can-We-Love-Obito/Z...     Single
# 80   https://zingmp3.vn/bai-hat/FriendZone-Obito/ZZ...     Single
# 161  https://zingmp3.vn/bai-hat/Boom-Lope-Pham-Obit...     Single
# 262  https://zingmp3.vn/bai-hat/When-You-Look-At-Me...     Single
# 283  https://zingmp3.vn/bai-hat/Dung-de-nuoc-mat-ro...     Single
# 286  https://zingmp3.vn/bai-hat/Shawty-VSOUL-Obito/...     Single
# 327  https://zingmp3.vn/bai-hat/No-Boundary-Richie-...         EP
# 328  https://zingmp3.vn/bai-hat/No-Boundary-Richie-...         EP

# %%
df.shape[0]
# Out:
# 47

# %%
df.to_excel('song_zingmp3.xlsx',index=False)

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

def get_artist_tracks_all(artist_name):
    client_id = "c7e1fe3ffe674920a01f9b016e6ae5df"
    client_secret = "215c6808dea74656b3629b306182ac4b"
    sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))
    
    # Tìm kiếm nghệ sĩ
    results = sp.search(q=artist_name, type='artist', limit=1)
    if not results['artists']['items']:
        print("Không tìm thấy nghệ sĩ.")
        return pd.DataFrame()
    
    artist_id = results['artists']['items'][0]['id']

    track_data = []
    query = f"artist:{artist_name}"
    search_results = sp.search(q=query, type='track', limit=50)  
    
    for track in search_results['tracks']['items']:
        track_title = track['name']
        link_spotify = track['external_urls']['spotify']
        album = track['album']
        album_name = album['name']
        album_release_date = album.get('release_date', 'Unknown')
        album_owner = album['artists'][0]['name']
        featured_artists = [artist['name'] for artist in track.get('artists', []) if artist['id'] != artist_id]
        featured_artists = ", ".join(featured_artists) if featured_artists else "None"

        
        # Lấy thông tin nhà cung cấp (label)
        album_id = album['id']
        album_info = sp.album(album_id)
        label = album_info.get('label', 'Unknown')

        try:
            album_release_date = pd.to_datetime(album_release_date, errors='coerce').strftime("%d/%m/%Y")
        except:
            album_release_date = "Unknown"
        
        track_data.append([
            album_name, track_title, album_release_date, 
            featured_artists if featured_artists else "None", 
            album_owner, label, link_spotify
        ])
    
    # Tạo DataFrame
    columns = ["album_name", "track_title", "release_date", "featured_artists", "album_owner", "label", "Link_Spotify"]
    df = pd.DataFrame(track_data, columns=columns)
    return df

if __name__ == "__main__":
    artist_name = 'Obito'
    df_tracks = get_artist_tracks_all(artist_name)

# %%
df_tracks.shape[0]
# Out:
# 50

# %%
df_tracks.to_excel('{artist_name}_song_spotify.xlsx',index=False)

# %%
df_tracks
# Out:
#                                            album_name  \
# 0                                                Lặng
# 1                                              ii-V-I
# 2                                            Đánh Đổi
# 3                                            Đánh Đổi
# 4   Buồn Hay Vui (feat. RPT MCK, Obito, Ronboogz &...
# 5                                            Đánh Đổi
# 6                                            Đánh Đổi
# 7                                            Đánh Đổi
# 8                                         Simple Love
# 9                                            Đánh Đổi
# 10                                        Shay nắnggg
# 11                                              VSTRA
# 12                                           Đánh Đổi
# 13                                               Lặng
# 14              When You Look at Me (feat. Seachains)
# 15                                           Đánh Đổi
# 16                                           Đánh Đổi
# 17                                           Đánh Đổi
# 18                                         Phong Long
# 19                                           Đánh Đổi
# 20                                           Đánh Đổi
# 44       Chỉ Cần Bạn Có Mặt (Ngày Hội Liên Quân 2024)   16/07/2024
# 45                                         FriendZone   10/06/2020
# 46                                        Can We Love   24/03/2022
# 47                              Happy Birthday To You   17/12/2021
# 48                                   Our Vintage Look   17/03/2022
# 49                                       Plata Blanca   25/02/2025
#
#                                      featured_artists       album_owner  \
# 0                                               Shiki             Shiki
# 1                                      Tyronee, VSTRA           Tyronee
# 2                                        Shiki, VSTRA             Obito
# 3                                      Shiki, RPT MCK             Obito
# 4                    VSOUL, RPT MCK, Ronboogz, Boyzed             VSOUL
# 5                                               Shiki             Obito
# 6                                      Shiki, Lăng LD             Obito
# 7                                               Shiki             Obito
# 8                                           Seachains             Obito
# 9                                               Shiki             Obito
# 10                                               AMEE              AMEE
# 11                               VSTRA, TGSN, Tyronee             VSTRA
# 12                                              Shiki             Obito
# 13                                              Shiki             Shiki
# 14                                          Seachains             Obito
# 15                                              Shiki             Obito
# 16                                              Shiki             Obito
# 17                                              Shiki             Obito
# 18                                      Low G, WOKEUP             Obito
# 19                                              Shiki             Obito
# 20                                              Shiki             Obito
# 21                                              Shiki             Obito
# 22                                              Shiki             Obito
# 23                                               None             Obito
# 24                                              VSOUL             VSOUL
# 25                             $A Milo, B-Wine, Gxxfy           $A Milo
# 26                     GREY D, HIEUTHUHAI, Wren Evans          WeChoice
# 27                                      Richie D. ICY     Richie D. ICY
# 28                                              Shiki             Obito
# 29                     GREY D, HIEUTHUHAI, Wren Evans   Various Artists
# 30          OCEAN MOB, Willistic, wAvy, Xolitxo, Gill         OCEAN MOB
# 31                                              Shiki             Obito
# 32                                               None             Obito
# 33                                               None             Obito
# 34                                              Shiki             Obito
# 35                                              Shiki             Obito
# 36                                              Shiki             Obito
# 37                                              Shiki             Obito
# 38  Mcredit, OCEAN MOB, wAvy, Willistic, Gill, XOL...           Mcredit
# 39                                           RAP VIỆT          RAP VIỆT
# 40                                               None             Obito
# 41                                     RAP VIỆT, Pjpo          RAP VIỆT
# 42                                        Hoàng Duyên       Hoàng Duyên
# 43                                           RAP VIỆT          RAP VIỆT
# 44                    Liên Quân Mobile, Wxrdie, Cheng  Liên Quân Mobile
# 45                                               None             Obito
# 46                                               None             Obito
# 47                                   AMEE, Hoàng Dũng              AMEE
# 48                                               None             Obito
# 49        Jakush314, Verzet, Krash, Prodigo, Kxtrplsx         Jakush314
#
#                                            label  \
# 0                                     12 trái lê
# 1                                     12 trái lê
# 2                                     12 trái lê
# 3                                     12 trái lê
# 4                                     12 trái lê
# 5                                     12 trái lê
# 6                                     12 trái lê
# 7                                     12 trái lê
# 8                                     12 trái lê
# 9                                     12 trái lê
# 10                                Yin Yang Media
# 11                                          CDSL
# 12                                    12 trái lê
# 13                                    12 trái lê
# 14                               NCT Corporation
# 15                                    12 trái lê
# 16                                    12 trái lê
# 17                                    12 trái lê
# 18  Universal Music Indochina Distributed Labels
# 19                                    12 trái lê
# 20                                    12 trái lê
# 21                                    12 trái lê
# 22                                    12 trái lê
# 23                                    12 trái lê
# 24                                    12 trái lê
# 35  https://open.spotify.com/track/5ljK6EfLvKJ3Za6...
# 36  https://open.spotify.com/track/7sJXPkaaKXcFKQf...
# 37  https://open.spotify.com/track/00QgTOAw8HREwIk...
# 38  https://open.spotify.com/track/2yPkB8nPmyk7Mvy...
# 39  https://open.spotify.com/track/0mc8HGMSYoMxRuJ...
# 40  https://open.spotify.com/track/4H2PEU1dQpwXYj2...
# 41  https://open.spotify.com/track/6wf0EooFR9eCHQ0...
# 42  https://open.spotify.com/track/1rCurScVWswOm8j...
# 43  https://open.spotify.com/track/0lCFmGlZNF6LGlZ...
# 44  https://open.spotify.com/track/7FXIgA9IiDbTB7V...
# 45  https://open.spotify.com/track/7L9tKmiK2AAwuhH...
# 46  https://open.spotify.com/track/7iXHkRf9Z4x6ona...
# 47  https://open.spotify.com/track/1XK0vd0S81wm61b...
# 48  https://open.spotify.com/track/1JODutZAd1ZeIw1...
# 49  https://open.spotify.com/track/33A73QGzYYx4769...

# %%
merged_df = df.merge(df_tracks, on="track_title", how="outer")
merged_df = merged_df.drop(columns=["album_name_y"])
merged_df = merged_df.rename(columns={"album_id":"Mã định danh album ZingMP3","album_name_x": "album_name","track_title":"tracklist(danh sách bài hát)","release_date_x": "Ngày phát hành trên ZingMP3","featured_artists_x":"Song artist(nghệ sĩ tham gia bài hát)","provided_by":"Cung cấp bởi","album_owner_x":'Album artist (nghệ sĩ sở hữu album)*',"linkzingmp3":"Link_ZingMP3",           	
"release_date_y": "Ngày phát hành trên Spotify","featured_artists_y":"Song artist(nghệ sĩ tham gia bài hát) trên S","label":"Cung cấp bởi","album_owner_y":'Album artist (nghệ sĩ sở hữu album)*'})
# desired_columns = [
#  "album_id","album_name","Album artist (nghệ sĩ sở hữu album)*","album_type","tracklist(danh sách bài hát)","Ngày phát hành trên ZingMP3","Cung cấp bởi","Song artist(nghệ sĩ tham gia bài hát)","Ngày phát hành trên Spotify", "Song artist(nghệ sĩ tham gia bài hát)","Album artist (nghệ sĩ sở hữu album)*","Cung cấp bởi","Mã định danh album ZingMP3","Link_ZingMP3","Link_Spotify"]
# merged_df = merged_df[desired_columns]
merged_df
# Out:
#     album_id                                         album_name  \
# 0   6CZ7U60W                                               Lặng
# 1   6BDOI9WU                                           Đánh Đổi
# 2   SC0EC0B6                                             OMERTÀ
# 3   6BDOI9WU                                           Đánh Đổi
# 4   6BDOI9WU                                           Đánh Đổi
# 5        N/A                                               Boom
# 6   6BEEZ96E  Buồn Hay Vui (feat. RPT MCK, Obito, Ronboogz &...
# 7   6BDOI9WU                                           Đánh Đổi
# 8   6BW0ICWD                               Can We Love (Single)
# 9   6BDOI9WU                                           Đánh Đổi
# 10  6BDOI9WU                                           Đánh Đổi
# 11  6CUCB0OO  Chỉ Cần Bạn Có Mặt (Ngày Hội Liên Quân 2024) (...
# 12  6BDOI9WU                                           Đánh Đổi
# 13  6BDOI9WU                                           Đánh Đổi
# 14  6BFZIF6B                                Dám Rực Rỡ (Single)
# 15  6BFZIF6B                                Dám Rực Rỡ (Single)
# 16       N/A                                         FriendZone
# 17  6BW6Z66W                     Happy Birthday To You (Single)
# 18  6BDOI9WU                                           Đánh Đổi
# 19  6BDOI9WU                                           Đánh Đổi
# 20  68EOUBE6                                      LOST (Single)
# 21  6BWO88DD                               Let's Leave (Single)
# 22  6BOEOFWO                                  Mưa Hồng (Single)
# 23       NaN                                                NaN
# 24       NaN                                                NaN
# 25  6BDOI9OI                               No Boundary (Single)
# 26  6BDOI9OI                               No Boundary (Single)
# 27  6BI96U0B                          Our Vintage Look (Single)
# 28  6BDOI9WU                                           Đánh Đổi
# 29  6BFOFUOD                                Phong Long (Single)
# 30       NaN                                                NaN
# 31       NaN                                                NaN
# 32  6BBFUC9Z                                    Shawty (Single)
# 33       N/A                                        Shay Nắnggg
# 34       NaN                                                NaN
# 35  6B6ZCOD6                                 Si me you (Single)
# 36  ZA9UAD8I                               Simple Love (Single)
# 37  6B0AIO0I                                 Soju Love (Single)
# 38  6BDOI9WU                                           Đánh Đổi
# 39  6CZ7U60W                                               Lặng
# 40  6BDOI9WU                                           Đánh Đổi
# 41  6B7C9ZO0         Tiền Là Chi (Mcredit x OCEAN MOB) (Single)
# 42  6C7IOCZ6                                        ii-V-I (EP)
# 43  6BDOI9WU                                           Đánh Đổi
# 44  6BDOI9WU                                           Đánh Đổi
# 45  6BDOI9WU                                           Đánh Đổi
# 46       NaN                                                NaN
# 47       N/A                         When You Look At Me (LENA)
# 48       N/A                                When You Look at Me
# 49       NaN                                                NaN
# 50  6BDOI9WU                                           Đánh Đổi
# 51  6BDOI9WU                                           Đánh Đổi
# 52  6BDOI9WU                                           Đánh Đổi
# 53  SBDAFBAF                                              VSTRA
# 54  6BDOI9WU                                           Đánh Đổi
#
#                          tracklist(danh sách bài hát)  \
# 0                                        1000 Ánh Mắt
# 1                                                  16
# 2                                       BUSINESS MODE
# 3                                 Backstage Freestyle
# 4                                 Biên Giới Long Bình
# 5                                                Boom
# 6   Buồn Hay Vui (feat. RPT MCK, Obito, Ronboogz &...
# 7                                     CL5 (interlude)
# 8                                         Can We Love
# 9                                            Champion
# 10                                          Chưa Xong
# 11       Chỉ Cần Bạn Có Mặt (Ngày Hội Liên Quân 2024)
# 12                                     Con kể Ba nghe
# 13                               Cất cánh (interlude)
# 14                                         Dám Rực Rỡ
# 15                                         Dám Rực Rỡ
# 16                                         FriendZone
# 17                              Happy Birthday To You
# 18                                             Hà Nội
# 19                                              Intro
# 20                                               LOST
# 21                                        Let's Leave
# 22                                           Mưa Hồng
# 23                    NGHE - NÓI (feat. Pjpo & Obito)
# 24                NGÀY MAI LÀ TƯƠNG LAI (feat. Obito)
# 25                                        No Boundary
# 26                         No Boundary (Instrumental)
# 27                                   Our Vintage Look
# 28                                              Outro
# 29                                         Phong Long
# 30                                       Plata Blanca
# 31                                     RAP CHO ANH EM
# 32                                             Shawty
# 33                                        Shay Nắnggg
# 34                                        Shay nắnggg
# 35                                          Si me you
# 36                                        Simple Love
# 37                                          Soju Love
# 38                                         Sài Gòn ơi
# 39                                Take Off Your Hands
# 40                          Tell the kids i love them
# 41                  Tiền Là Chi (Mcredit x OCEAN MOB)
# 42                                           Track 06
# 43                                          Trốn Chạy
# 44                                              Tự Sự
# 45                                       Vô Điều Kiện
# 46                      VẪN LÀ TRAI TỐT (feat. Obito)
# 47                         When You Look At Me (LENA)
# 48                                When You Look at Me
# 49              When You Look at Me (feat. Seachains)
# 50                                     Xuất Phát Điểm
# 51                                           Đánh Đổi
# 52                                   Đầu Đường Xó Chợ
# 53                 Đừng để nước mắt rơi (feat. Obito)
# 54                          Ước mơ của Mẹ (interlude)
#
#    Ngày phát hành trên ZingMP3             Cung cấp bởi  \
# 0                   27/06/2024     Warner Music Vietnam
# 1                   10/10/2023     Warner Music Vietnam
# 2                   17/05/2024  DAO Music Entertainment
# 3                   10/10/2023     Warner Music Vietnam
# 4                   10/10/2023     Warner Music Vietnam
# 5                         None                     None
# 6                   25/12/2023     Warner Music Vietnam
# 7                   10/10/2023     Warner Music Vietnam
# 8                   24/03/2022    Universal Music Group
# 9                   10/10/2023     Warner Music Vietnam
# 10                  10/10/2023     Warner Music Vietnam
# 11                  16/07/2024           TECHBEAT Music
# 12                  10/10/2023     Warner Music Vietnam
# 13                  10/10/2023     Warner Music Vietnam
# 14                  23/01/2024    Universal Music Group
# 15                  23/01/2024    Universal Music Group
# 16                        None                     None
# 17                  17/12/2021           Yin Yang Media
# 18                  10/10/2023     Warner Music Vietnam
# 19                  10/10/2023     Warner Music Vietnam
# 20                  25/09/2020    Universal Music Group
# 21                  01/04/2022    Universal Music Group
# 22                  14/06/2022    Universal Music Group
# 23                         NaN                      NaN
# 24                         NaN                      NaN
# 25                  03/10/2023     Warner Music Vietnam
# 26                  03/10/2023     Warner Music Vietnam
# 27                  17/03/2022    Universal Music Group
# 28                  10/10/2023     Warner Music Vietnam
# 29                  20/01/2024    Universal Music Group
# 30                         NaN                      NaN
# 31                         NaN                      NaN
# 32                  23/07/2023     Warner Music Vietnam
# 33                        None                     None
# 34                         NaN                      NaN
# 35                  10/10/2022     Warner Music Vietnam
# 36                  28/11/2022     Warner Music Vietnam
# 37                  08/03/2022    Universal Music Group
# 38                  10/10/2023     Warner Music Vietnam
# 39                  27/06/2024     Warner Music Vietnam
# 40                  10/10/2023     Warner Music Vietnam
# 41                  22/12/2022                    MIXUS
# 42                  05/12/2024     Warner Music Vietnam
# 43                  10/10/2023     Warner Music Vietnam
# 44                  10/10/2023     Warner Music Vietnam
# 45                  10/10/2023     Warner Music Vietnam
# 46                         NaN                      NaN
# 47                        None                     None
# 48                        None                     None
# 49                         NaN                      NaN
# 50                  10/10/2023     Warner Music Vietnam
# 51                  10/10/2023     Warner Music Vietnam
# 52                  10/10/2023     Warner Music Vietnam
# 53                  11/11/2023              The Orchard
# 54                  10/10/2023     Warner Music Vietnam
#
#                Song artist(nghệ sĩ tham gia bài hát)  \
# 0                                       Shiki, Obito
# 1                              Obito, Shiki, Lăng LD
# 2                      $A Milo, Gxxfy, Obito, B-Wine
# 3                              Obito, Shiki, Lăng LD
# 4                              Obito, Shiki, Lăng LD
# 5                                   Lope Phạm, Obito
# 6                VSOUL, MCK, Obito, Ronboogz, Boyzed
# 7                              Obito, Shiki, Lăng LD
# 8                                              Obito
# 9                              Obito, Shiki, Lăng LD
# 10                             Obito, Shiki, Lăng LD
# 11     Obito, Wxrdie, Cheng, Garena Liên Quân Mobile
# 12                             Obito, Shiki, Lăng LD
# 13                             Obito, Shiki, Lăng LD
# 14             GREY D, HIEUTHUHAI, Wren Evans, Obito
# 15             GREY D, HIEUTHUHAI, Wren Evans, Obito
# 16                                             Obito
# 17                           AMEE, Hoàng Dũng, Obito
# 18                             Obito, Shiki, Lăng LD
# 19                             Obito, Shiki, Lăng LD
# 20                                             Obito
# 21                                             Obito
# 22                                Hoàng Duyên, Obito
# 23                                               NaN
# 24                                               NaN
# 25                              Richie D. ICY, Obito
# 26                              Richie D. ICY, Obito
# 27                                             Obito
# 28                             Obito, Shiki, Lăng LD
# 29                              Low G, Obito, WOKEUP
# 30                                               NaN
# 31                                               NaN
# 32                                      VSOUL, Obito
# 33                                       AMEE, Obito
# 34                                               NaN
# 35                                             Obito
# 36                           Obito, Seachains, Davis
# 37                                             Obito
# 38                             Obito, Shiki, Lăng LD
# 39                                      Shiki, Obito
# 40                             Obito, Shiki, Lăng LD
# 41  OCEAN MOB, wAvy, Willistic, Gill, xolitxo, Obito
# 42                             Tyronee, VSTRA, Obito
# 43                             Obito, Shiki, Lăng LD
# 44                             Obito, Shiki, Lăng LD
# 45                             Obito, Shiki, Lăng LD
# 46                                               NaN
# 47                                  Obito, Seachains
# 48                                             Obito
# 49                                               NaN
# 50                             Obito, Shiki, Lăng LD
# 51                             Obito, Shiki, Lăng LD
# 52                             Obito, Shiki, Lăng LD
# 53                       VSTRA, TGSN, Tyronee, Obito
# 54                             Obito, Shiki, Lăng LD
#
#                Album artist (nghệ sĩ sở hữu album)*  \
# 0                                             Shiki
# 1                                      Obito, Shiki
# 2                                    $A Milo, Gxxfy
# 3                                      Obito, Shiki
# 4                                      Obito, Shiki
# 5                                              None
# 6               VSOUL, MCK, Obito, Ronboogz, Boyzed
# 7                                      Obito, Shiki
# 8                                             Obito
# 9                                      Obito, Shiki
# 10                                     Obito, Shiki
# 11    Obito, Wxrdie, Cheng, Garena Liên Quân Mobile
# 12                                     Obito, Shiki
# 13                                     Obito, Shiki
# 14  GREY D, HIEUTHUHAI, Wren Evans, Obito, Kai Đinh
# 15  GREY D, HIEUTHUHAI, Wren Evans, Obito, Kai Đinh
# 16                                             None
# 17                          AMEE, Hoàng Dũng, Obito
# 18                                     Obito, Shiki
# 19                                     Obito, Shiki
# 20                                            Obito
# 21                                            Obito
# 22                               Hoàng Duyên, Obito
# 23                                              NaN
# 24                                              NaN
# 25                             Richie D. ICY, Obito
# 26                             Richie D. ICY, Obito
# 27                                            Obito
# 28                                     Obito, Shiki
# 29                             Obito, Low G, WOKEUP
# 30                                              NaN
# 31                                              NaN
# 32                                     VSOUL, Obito
# 33                                             None
# 34                                              NaN
# 35                                            Obito
# 36                                 Obito, Seachains
# 37                                            Obito
# 38                                     Obito, Shiki
# 39                                            Shiki
# 40                                     Obito, Shiki
# 41                                        OCEAN MOB
https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
# 53  https://zingmp3.vn/bai-hat/Dung-de-nuoc-mat-ro...     Single
# 54  https://zingmp3.vn/bai-hat/Dau-Duong-Xo-Cho-Ob...    Regular
#
#    Ngày phát hành trên Spotify  \
# 0                   27/06/2024
# 1                   10/10/2023
# 2                   18/05/2024
# 3                   10/10/2023
# 4                   10/10/2023
# 5                          NaN
# 6                   25/12/2023
# 7                   10/10/2023
# 8                   24/03/2022
# 9                   10/10/2023
# 10                  10/10/2023
# 11                  16/07/2024
# 12                  10/10/2023
# 13                  10/10/2023
# 14                  25/01/2024
# 15                  23/01/2024
# 16                  10/06/2020
# 17                  17/12/2021
# 18                  10/10/2023
# 19                  10/10/2023
# 20                  24/09/2020
# 21                  01/04/2022
# 22                  14/06/2022
# 23                  22/12/2021
# 24                  22/11/2021
# 25                  03/10/2023
# 26                         NaN
# 27                  17/03/2022
# 28                  10/10/2023
# 29                  20/01/2024
# 30                  25/02/2025
# 31                  04/12/2020
# 32                  24/07/2023
# 33                         NaN
# 34                  06/06/2022
# 35                  09/10/2022
# 36                  28/11/2022
# 37                  08/03/2022
# 38                  10/10/2023
# 39                  27/06/2024
# 40                  10/10/2023
# 41                  22/12/2022
# 42                  05/12/2024
# 43                  10/10/2023
# 44                  10/10/2023
# 45                  10/10/2023
# 46                  03/01/2022
# 47                         NaN
# 48                         NaN
# 49                  23/12/2019
# 50                  10/10/2023
# 51                  10/10/2023
# 52                  10/10/2023
# 53                  11/11/2023
# 54                  10/10/2023
#
#                 Song artist(nghệ sĩ tham gia bài hát)  \
# 0                                               Shiki
# 1                                               Shiki
# 2                              $A Milo, B-Wine, Gxxfy
# 3                                               Shiki
# 4                                               Shiki
# 5                                                 NaN
# 6                    VSOUL, RPT MCK, Ronboogz, Boyzed
# 7                                               Shiki
# 8                                                None
# 9                                               Shiki
# 10                                              Shiki
# 11                    Liên Quân Mobile, Wxrdie, Cheng
# 12                                              Shiki
# 13                                              Shiki
# 14                     GREY D, HIEUTHUHAI, Wren Evans
# 15                     GREY D, HIEUTHUHAI, Wren Evans
# 16                                               None
# 17                                   AMEE, Hoàng Dũng
# 18                                       Shiki, VSTRA
# 19                                              Shiki
# 20                                               None
# 21                                               None
# 22                                        Hoàng Duyên
# 23                                     RAP VIỆT, Pjpo
# 24                                           RAP VIỆT
# 25                                      Richie D. ICY
# 26                                                NaN
# 27                                               None
# 28                                              Shiki
# 29                                      Low G, WOKEUP
# 30        Jakush314, Verzet, Krash, Prodigo, Kxtrplsx
# 31          OCEAN MOB, Willistic, wAvy, Xolitxo, Gill
# 32                                              VSOUL
# 33                                                NaN
# 34                                               AMEE
# 35                                               None
# 36                                          Seachains
# 37                                               None
# 38                                              Shiki
# 39                                              Shiki
# 40                                              Shiki
# 41  Mcredit, OCEAN MOB, wAvy, Willistic, Gill, XOL...
# 42                                     Tyronee, VSTRA
# 43                                              Shiki
# 44                                              Shiki
# 45                                              Shiki
# 46                                           RAP VIỆT
# 47                                                NaN
# 48                                                NaN
# 49                                          Seachains
# 50                                              Shiki
# 51                                     Shiki, RPT MCK
# 52                                     Shiki, Lăng LD
# 53                               VSTRA, TGSN, Tyronee
# 54                                              Shiki
#
#    Album artist (nghệ sĩ sở hữu album)*  \
# 0                                 Shiki
# 1                                 Obito
# 2                               $A Milo
# 3                                 Obito
# 4                                 Obito
# 5                                   NaN
# 6                                 VSOUL
# 7                                 Obito
# 8                                 Obito
# 9                                 Obito
# 10                                Obito
# 11                     Liên Quân Mobile
# 12                                Obito
# 13                                Obito
# 14                             WeChoice
# 15                      Various Artists
# 16                                Obito
# 17                                 AMEE
# 18                                Obito
# 19                                Obito
# 20                                Obito
# 21                                Obito
# 22                          Hoàng Duyên
# 23                             RAP VIỆT
# 24                             RAP VIỆT
# 25                        Richie D. ICY
# 26                                  NaN
# 27                                Obito
# 28                                Obito
# 29                                Obito
# 30                            Jakush314
# 31                            OCEAN MOB
# 32                                VSOUL
# 33                                  NaN
# 34                                 AMEE
# 35                                Obito
# 36                                Obito
# 37                                Obito
# 38                                Obito
# 39                                Shiki
# 40                                Obito
# 41                              Mcredit
# 42                              Tyronee
# 43                                Obito
# 44                                Obito
# 45                                Obito
# 46                             RAP VIỆT
# 47                                  NaN
# 48                                  NaN
# 49                                Obito
# 50                                Obito
# 51                                Obito
# 52                                Obito
# 53                                VSTRA
# 54                                Obito
#
#                                     Cung cấp bởi  \
# 0                                     12 trái lê
# 1                                     12 trái lê
# 2                                   MaiDao Music
# 3                                     12 trái lê
# 4                                     12 trái lê
# 5                                            NaN
# 6                                     12 trái lê
# 7                                     12 trái lê
# 8                      Universal Music Indochina
# 9                                     12 trái lê
# 10                                    12 trái lê
# 11                                          TBRC
# 12                                    12 trái lê
# 13                                    12 trái lê
# 14                     Universal Music Indochina
# 15                     Universal Music Indochina
# 16                                Yin Yang Media
# 17                                Yin Yang Media
# 18                                    12 trái lê
# 19                                    12 trái lê
# 20                     Universal Music Indochina
# 21                     Universal Music Indochina
# 22  Universal Music Indochina Distributed Labels
# 23                                  DAT VIET VAC
# 24                                  DAT VIET VAC
# 25                                    12 trái lê
# 26                                           NaN
# 27                     Universal Music Indochina
# 28                                    12 trái lê
# 29  Universal Music Indochina Distributed Labels
# 30                                   Independent
# 31  Universal Music Indochina Distributed Labels
# 32                                    12 trái lê
# 33                                           NaN
# 34                                Yin Yang Media
# 35                                    12 trái lê
# 36                                    12 trái lê
# 37                     Universal Music Indochina
# 38                                    12 trái lê
# 39                                    12 trái lê
# 40                                    12 trái lê
# 41                                         MIXUS
# 42                                    12 trái lê
# 43                                    12 trái lê
# 44                                    12 trái lê
# 45                                    12 trái lê
# 46                                  DAT VIET VAC
# 47                                           NaN
# 48                                           NaN
# 49                               NCT Corporation
# 50                                    12 trái lê
# 51                                    12 trái lê
# 52                                    12 trái lê
# 53                                          CDSL
# 54                                    12 trái lê
#
#                                          Link_Spotify
# 0   https://open.spotify.com/track/5XfGQZA0ioQAWUj...
# 1   https://open.spotify.com/track/3jwzesnDs0jY7Ke...
# 2   https://open.spotify.com/track/1nLkB5tZaxAIbJ7...
# 3   https://open.spotify.com/track/6Kvm6QRtOOM6bMe...
# 4   https://open.spotify.com/track/5KXRShxe6Y54ueB...
# 5                                                 NaN
columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print("Columns in df_spotify:", df_spotify.columns)
#       2 print("Columns in df_zingmp3:", df_zingmp3.columns)
#
# NameError: name 'df_spotify' is not defined

# %%
def preprocess_dataframe(df):
    print("Available columns before renaming:", df.columns)  # Kiểm tra cột trước khi đổi tên
    
    # Đổi tên cột về chuẩn (viết thường, không có khoảng trắng)
    column_mapping = {
        "Track Title": "track_title",
        "Release Date": "release_date",
        "Zing Release Date": "release_date",
        "Zing Featured Artists": "featured_artists",
        "Featured Artists": "featured_artists",
        "Zing Album Owner": "album_owner",
        "Album Owner": "album_owner",
        "Zing MP3 Link": "linkzingmp3",
        "Spotify Link": "spotify_link",
        "Album ID": "album_id"
    }
    df = df.rename(columns=column_mapping)

    print("Available columns after renaming:", df.columns)  # Kiểm tra sau khi đổi tên

    # Kiểm tra xem các cột quan trọng có tồn tại không
    required_columns = ["track_title", "release_date", "album_id", "album_name"]
    missing_columns = [col for col in required_columns if col not in df.columns]
    
    if missing_columns:
        raise ValueError(f"Missing required columns: {missing_columns}")

    # Chuẩn hóa dữ liệu
    df["track_title"] = df["track_title"].astype(str).apply(normalize_song_title)
    df["release_date"] = df["release_date"].astype(str).apply(normalize_date)
    
    # Loại bỏ trùng lặp dựa trên (album_id, album_name, track_title)
    df = df.drop_duplicates(subset=["album_id", "album_name", "track_title"])
    
    return df

# %%
import requests
import pandas as pd
import re
import unicodedata

def normalize_title(title):
    """Chuẩn hóa tên bài hát: bỏ dấu, ký tự đặc biệt, viết thường, xóa khoảng trắng thừa"""
    title = title.lower()  # Chuyển về chữ thường
    title = unicodedata.normalize('NFKD', title).encode('ascii', 'ignore').decode('utf-8')  # Loại bỏ dấu tiếng Việt
    title = re.sub(r'[^a-z0-9\s]', '', title)  # Xóa ký tự đặc biệt, chỉ giữ chữ cái và số
    title = re.sub(r'\s+', ' ', title).strip()  # Xóa khoảng trắng thừa
    return title

def extract_album_id(album_link):
    match = re.search(r'/album/.*?/(\w+)\.html', album_link or "")
    return match.group(1) if match else "N/A"

def fetch_artist_songs(artist_name):
    url = f"http://localhost:5000/api/artistsongs?name={artist_name}"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        songs = data.get("songs", [])

        records = []
        for song in songs:
            tracklist = song.get("tracklist", [])
            
            if not tracklist:
                tracklist = [{"title": song.get("title", "N/A")}]  # Nếu không có danh sách bài hát, lấy luôn tên bài hát
            
            album_id = extract_album_id(song.get("albumLink", "") or "")
            
            for track in tracklist:
                records.append({
                    "album_id": album_id,
                    "album_name": song.get("album", song.get("title", "N/A")),
                    "track_title": normalize_title(track["title"]),  # Chuẩn hóa tên bài hát
                    "release_date": song.get("releaseDate", "Unknown"),
                    "provided_by": song.get("providedBy", "Unknown"),
                    "featured_artists": song.get("featuredArtists", "Unknown"),
                    "album_owner": song.get("albumOwner", "Unknown"),
                    "linkzingmp3": song.get("link", "N/A")
                })
        
        df = pd.DataFrame(records)
        df = df.drop_duplicates(subset=["album_id", "album_name", "track_title"])
        return df
    else:
        print("Error fetching data:", response.status_code)
        return None

df = fetch_artist_songs("Obito")
